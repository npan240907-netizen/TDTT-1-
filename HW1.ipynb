# %% [markdown]
# Bài 1: Nhập vào số nguyên n, in ra màn hình số gấp đôi của n

# %%
a=int(input("nhập số nguyên a:"))
print("số gấp đôi của a là ",a * 2)
# Out:
# số gấp đôi của a là  40

# %% [markdown]
# Bài 2: Một khu đất hình chữ nhật có chiều rộng a, chiều dài b. Người ra xây một khu
# vui chơi hình tròn tại vị trí trung tâm khu đất như hình vẽ. Nhập vào a, b. Hãy tính phần
# diện tích còn để trồng cây xung quanh là bao nhiêu. Biết pi = 3.14, lấy kết quả đến 2
# chữ số phần thập phân.

# %%
a=float(input("nhập chiều rộng:")) 
b=float(input("nhập chiều dài:"))
S=a*b
Y=min(a, b)/2
T=3.14*Y**2
print("diện tích hình chữ nhập là:", S)
print("diện tích hình tròn là:", T)
U=S-T
print("diện tích phần còn lại là:", U)
# Out:
# diện tích hình chữ nhập là: 200.0
# diện tích hình tròn là: 78.5
# diện tích phần còn lại là: 121.5

# %% [markdown]
# Bài 3: Viết chương trình nhập vào một “kí tự” c, nếu nó là chữ hoa thì in ra chữ thường
# tương ứng và ngược lại nếu nó là chữ thường thì in ra chữ hoa tương ứng của nó. (xem
# trước cấu trúc lựa chọn: if….else, ma)

# %%
c=input("nhập 1 kí tự:")
if c.isupper():
    print("chữ thường tương ứng là:", c.lower())
elif c.islower():
    print("chữ hoa tương ứng là:", c.upper())
else:
    print("kí tự đã nhập không phải là chữ cái")
# Out:
# chữ hoa tương ứng là: D

# %% [markdown]
# Bài 4: Viết chương trình nhập vào một “kí tự”, Kiểm tra xem c có phải là kí tự chữ cái
# không (hoa hoặc thường). Nếu đúng thì in ra “{c} là kí tu alphabet”, nếu sai in ra “{c}
# không phải là kí tự alphabet

# %%
c=input("Nhập 1 kí tự ")
if c.isalpha():
    print("c là kí tự alphabet")
else:
    print("c ko là kí tự alphabet")
# Out:
# c là kí tự alphabet

# %% [markdown]
# Bài 5: Nhập vào chữ cái hoa A, in ra chữ cái thường liền trước chữ cái a thường tương
# ứng của A. Xét TH khi c = ‘A’ là đặc biệt.

# %% [markdown]
# Bài 6. Nhập vào 3 số a, b, c. Kiểm tra xem đây có phải là cạnh của 1 tam giác không,
# nếu đúng thì tính diện tích của tam giác đó, in ra với 1 chữ số phần thập phân, nếu nó
# không phải 3 cạnh của tam giác thì in ra “Khong phai 3 canh cua tam giac”.

# %%
a=float(input("nhập chiều a:"))
b=float(input("nhập chiều b:"))
c=float(input("nhập chiều c:"))
if a+b>c and a+c>b and b+c>a and a>0 and b>0 and c>0:
    print("3 cạnh trên có thể tạo thành 1 tam giác")
    p=(a+b+c)/2
    S=(p*(p-a)*(p-b)*(p-c))**0.5
    print ("diện tích tam giác là:", S)

else:
    print("3 cạnh trên không thể tạo thành 1 tam giác")
# Out:
# 3 cạnh trên có thể tạo thành 1 tam giác
# diện tích tam giác là: 6.0

# %% [markdown]
# Bài 7: Nhập vào một chuỗi gồm các kí tự thường độ dài >=20, in ra chữ cái thứ năm và
# thứ chín của chuỗi này.

# %%
a=input("nhập 1 chuỗi kí tự >=20 kí tự:")
if len(a)>=20:
    print("in ra chữ cái thứ 5:", a[4])
    print("in ra chữ cái thứ 10:", a[9])

# %% [markdown]
# Bài 8: Nhập vào họ tên chủ hộ và chỉ số điện kế tháng trước và chỉ số điện kế tháng này,
# tính tiền điện tháng này cho hộ biết:
# - Từ 0 – 50kWh: 1.984 đồng/kWh
# - Bậc 2: Từ 51 – 100 kWh: 2.050 đồng/
# - Bậc 5: Từ 301 – 400 kWh: 3.350 đồng/kWh
# - Bậc 6: Từ 401 trở đi kWh: 3.460 đồng/kWh
# Tính thêm tiền VAT 8%. Chỉ lấy đến đơn vị đồng

# %%
a = float(input("chỉ số tháng tước:"))
b = float(input("chỉ số tháng sau:"))
name = input(" nhập tên chủ hộ:")
c = b - a
if c<=50:
    print(f"chủ hộ {name} đã sử dụng {c} số điện, tiền điện phải trả là: {c*1984+c*1984*0.08} đồng")
elif c>50 and c<=100:
    print(f"chủ hộ {name} đã sử dụng {c} số điện, tiền điện phải trả là: {50*1984+ (c-50)*2050 + (50*1984+ (c-50)*2050)*0.08} đồng")
elif c>100 and c<=200:
    print(f"chủ hộ {name} đã sử dụng {c} số điện, tiền điện phải trả là: {50*1984+ 50*2050 + (c-100)*2380 + (50*1984+ 50*2050 + (c-100)*2380)*0.08} đồng")
elif c>200 and c<=300:
    print(f"chủ hộ {name} đã sử dụng {c} số điện, tiền điện phải trả là: {50*1984+ 50*2050 + 100*2380 + (c-200)*2998 + (50*1984+ 50*2050 + 100*2380 + (c-200)*2998)*0.08} đồng")
elif c>300:
    print(f"chủ hộ {name} đã sử dụng {c} số điện, tiền điện phải trả là: {50*1984+ 50*2050 + 100*2380 + 100*2998 + (c-300)*3350 + (50*1984+ 50*2050 + 100*2380 + 100*2998 + (c-300)*3350)*0.08} đồng")
